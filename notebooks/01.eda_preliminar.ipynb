# %%
# Tratamiento de datos
import pandas as pd
pd.set_option("display.max_columns", None)

# Exploración de archivos
import sys
sys.path.append('../') # necesito esto para la siguiente línea de código; para que busque src en una carpeta anterior

# Funciones personalizadas
from src import sp_eda as se # he creado una función (eda_preliminar) que ahora está en el archivo src y por eso lo estoy importando

# %%
df = pd.read_csv("../data/data_raw.csv") # los dos puntos son para ir una carpeta hacia atrás respectoa dónde está el archivo jupyter

# %%
se.eda_preliminar(df) # aquí llamo a la función de mi archivo que tiene el alias se
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 183       184     B  2022-01-27           0           SPORTS      P1561
# 560       561     B  2022-02-03           0           BEAUTY      P1177
# 466       467     A  2022-03-31           0             TOYS      P1591
# 745       746     B  2022-01-19           0      ELECTRONICS      P1076
# 1736     1737     A  2022-01-10           0             TOYS      P1175
#
#        Product Name  Quantity   Price Discount Total Value Payment Method  \
# 183        Football         0  101,86     0,28         0,0            NaN
# 560         Perfume         0   79,84      0,0         0,0            NaN
# 466   Action Figure         0   47,59      0,0         0,0            NaN
# 745      Headphones         0  220,34     0,28         0,0            NaN
# 1736         Puzzle         0   48,94     0,25         0,0            NaN
#
#      Shipping Method Region  Customer Age Customer Gender   Device  \
# ...

# %%
df.sample(5)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 187       188     B  2022-03-09           0             TOYS      P1593
# 431       432     B  2022-03-03           0             TOYS      P1100
# 1086     1087     B  2022-01-26           0             HOME      P1157
# 1283     1284     A  2022-01-03           0         FASHHION      P1559
# 1790     1791     A  2022-01-25           0           SPORTS      P1030
#
#      Product Name  Quantity   Price Discount Total Value Payment Method  \
# 187    Board Game         0    57,9     0,29         0,0            NaN
# 431    Board Game         0    85,1     0,02         0,0            NaN
# 1086         Sofa         0  330,34     0,29         0,0            NaN
# 1283      T-shirt         0  104,47     0,18         0,0            NaN
# 1790     Football         0  156,36     0,16         0,0            NaN
#
#      Shipping Method   Region  Customer Age Customer Gender   Device  \
# ...

# %%
print(f"Mi data frame tiene {df.shape[0]} filas y {df.shape[1]} columnas")
# Out:
# Mi data frame tiene 2000 filas y 21 columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User Id           2000 non-null   int64
#  1   Group             2000 non-null   object
#  2   Visit Date        2000 non-null   object
#  3   Conversion        2000 non-null   int64
#  4   Product Category  2000 non-null   object
#  5   Product Id        2000 non-null   object
#  6   Product Name      2000 non-null   object
#  7   Quantity          2000 non-null   int64
#  8   Price             1960 non-null   object
#  9   Discount          1960 non-null   object
#  10  Total Value       2000 non-null   object
#  11  Payment Method    247 non-null    object
#  12  Shipping Method   247 non-null    object
#  13  Region            2000 non-null   object
#  14  Customer Age      1960 non-null   float64
#  15  Customer Gender   2000 non-null   object
# ...

# %%
df.isnull().sum()/ df.shape[0] * 100
# Out:
# User Id              0.00
# Group                0.00
# Visit Date           0.00
# Conversion           0.00
# Product Category     0.00
# Product Id           0.00
# Product Name         0.00
# Quantity             0.00
# Price                2.00
# Discount             2.00
# Total Value          0.00
# Payment Method      87.65
# Shipping Method     87.65
# Region               0.00
# Customer Age         2.00
# Customer Gender      0.00
# Device               0.00
# Session Duration     0.00
# Coupon Used         87.65
# Browser              0.00
# Referral Source      0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.select_dtypes(include="O").columns:
  print(col.upper())
  print(df[col].value_counts())
  print('-----------')
# Out:
# GROUP
# Group
# B    1013
# A     987
# Name: count, dtype: int64
# -----------
# VISIT DATE
# Visit Date
# 2022-01-28    35
# 2022-02-16    34
# 2022-02-28    32
# 2022-01-19    31
# 2022-01-21    31
#               ..
# 2022-01-18    15
# 2022-03-21    14
# 2022-03-30    14
# 2022-02-21    12
# 2022-01-31    10
# Name: count, Length: 90, dtype: int64
# -----------
# PRODUCT CATEGORY
# Product Category
# FASHHION       321
# BOOKS          291
# HOME           287
# SPORTS         282
# TOYS           276
# ELECTRONICS    275
# BEAUTY         268
# Name: count, dtype: int64
# -----------
# PRODUCT ID
# Product Id
# P1416    8
# P1782    8
# P1848    7
# P1605    7
# P1798    7
#         ..
# P1774    1
# P1096    1
# P1120    1
# P1196    1
# P1805    1
# Name: count, Length: 867, dtype: int64
# -----------
# PRODUCT NAME
# Product Name
# Science Fiction    85
# Smartphone         84
# Jeans              84
# Mystery            82
# Table              82
# Sofa               82
# ...
