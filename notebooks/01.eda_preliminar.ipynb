# %%
# Tratamiento de datos
import pandas as pd
pd.set_option("display.max_columns", None)

# Exploración de archivos
import sys
sys.path.append('../') # necesito esto para la siguiente línea de código; para que busque src en una carpeta anterior

# Funciones personalizadas
from src import sp_eda as se # he creado una función (eda_preliminar) que ahora está en el archivo src y por eso lo estoy importando

# %%
df = pd.read_csv("../data/data_raw.csv") # los dos puntos son para ir una carpeta hacia atrás respectoa dónde está el archivo jupyter

# %%
se.eda_preliminar(df) # aquí llamo a la función de mi archivo que tiene el alias se
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 680       681     B  2022-03-11           0             HOME      P1731
# 1190     1191     A  2022-03-12           0      ELECTRONICS      P1946
# 800       801     B  2022-02-03           0            BOOKS      P1849
# 676       677     A  2022-01-20           0      ELECTRONICS      P1958
# 150       151     B  2022-03-25           1           SPORTS      P1800
#
#      Product Name  Quantity   Price Discount Total Value Payment Method  \
# 680         Table         0   371,4     0,09         0,0            NaN
# 1190   Headphones         0  624,21     0,01         0,0            NaN
# 800     Biography         0    31,2     0,04         0,0            NaN
# 676    Smartphone         0   331,7      0,1         0,0            NaN
# 150      Football         3   37,52     0,24       85,55  Bank Transfer
#
#      Shipping Method Region  Customer Age Customer Gender   Device  \
# 680              NaN   West          37.0               M   TABLET
# 1190             NaN   West          65.0               M   TABLET
# 800              NaN  North          58.0               F   TABLET
# 676              NaN   East          58.0               F  Desktop
# 150         Same day  North          48.0               M  Desktop
#
#       Session Duration Coupon Used       Browser Referral Source
# 680                 14         NaN       Eddddge         Organic
# 1190                12         NaN  Firefoxxxxxx           Email
# 800                  8         NaN       Eddddge          Social
# 676                 24         NaN      Chrooome         Organic
# 150                 14          No       Eddddge           Email
# -----------------------------
# DIMENSIONES
# Mi data frame tiene 2000 filas y 21 columnas
# -----------------------------
# INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User Id           2000 non-null   int64
#  1   Group             2000 non-null   object
#  2   Visit Date        2000 non-null   object
#  3   Conversion        2000 non-null   int64
#  4   Product Category  2000 non-null   object
#  5   Product Id        2000 non-null   object
#  6   Product Name      2000 non-null   object
#  7   Quantity          2000 non-null   int64
#  8   Price             1960 non-null   object
#  9   Discount          1960 non-null   object
#  10  Total Value       2000 non-null   object
#  11  Payment Method    247 non-null    object
#  12  Shipping Method   247 non-null    object
#  13  Region            2000 non-null   object
#  14  Customer Age      1960 non-null   float64
#  15  Customer Gender   2000 non-null   object
#  16  Device            2000 non-null   object
#  17  Session Duration  2000 non-null   int64
#  18  Coupon Used       247 non-null    object
#  19  Browser           2000 non-null   object
#  20  Referral Source   2000 non-null   object
# dtypes: float64(1), int64(4), object(16)
# memory usage: 328.3+ KB
# None
# -----------------------------
# NULOS
# User Id              0.00
# Group                0.00
# Visit Date           0.00
# Conversion           0.00
# Product Category     0.00
# Product Id           0.00
# Product Name         0.00
# Quantity             0.00
# Price                2.00
# Discount             2.00
# Total Value          0.00
# Payment Method      87.65
# Shipping Method     87.65
# Region               0.00
# Customer Age         2.00
# Customer Gender      0.00
# Device               0.00
# Session Duration     0.00
# Coupon Used         87.65
# Browser              0.00
# Referral Source      0.00
# dtype: float64
# -----------------------------
# DUPLICADOS
# Tenemos un total de 0 duplicados
# -----------------------------
# FRECUENCIA CATEGORICAS
# GROUP
# Group
# B    1013
# A     987
# Name: count, dtype: int64
# -----------
# VISIT DATE
# Visit Date
# 2022-01-28    35
# 2022-02-16    34
# 2022-02-28    32
# 2022-01-19    31
# 2022-01-21    31
#               ..
# 2022-01-18    15
# 2022-03-21    14
# 2022-03-30    14
# 2022-02-21    12
# 2022-01-31    10
# Name: count, Length: 90, dtype: int64
# -----------
# PRODUCT CATEGORY
# Product Category
# FASHHION       321
# BOOKS          291
# HOME           287
# SPORTS         282
# TOYS           276
# ELECTRONICS    275
# BEAUTY         268
# Name: count, dtype: int64
# -----------
# PRODUCT ID
# Product Id
# P1416    8
# P1782    8
# P1848    7
# P1605    7
# P1798    7
#         ..
# P1774    1
# P1096    1
# P1120    1
# P1196    1
# P1805    1
# Name: count, Length: 867, dtype: int64
# -----------
# PRODUCT NAME
# Product Name
# Science Fiction    85
# Smartphone         84
# Jeans              84
# Mystery            82
# Table              82
# Sofa               82
# Dress              81
# Sneakers           81
# Football           77
# Action Figure      75
# T-shirt            75
# Mascara            74
# Doll               73
# Headphones         72
# Lamp               72
# Running Shoes      72
# Tennis Racket      72
# Perfume            71
# Novel              69
# Lipstick           69
# Board Game         69
# Gym Bag            61
# Camera             60
# Puzzle             59
# Laptop             59
# Biography          55
# Lotion             54
# Chair              51
# Name: count, dtype: int64
# -----------
# PRICE
# Price
# 19,99     3
# 47,83     2
# 193,17    2
# 22,8      2
# 38,12     2
#          ..
# 198,08    1
# 14,01     1
# 498,58    1
# 102,32    1
# 7,8       1
# Name: count, Length: 1887, dtype: int64
# -----------
# DISCOUNT
# Discount
# 0,08    76
# 0,21    76
# 0,27    75
# 0,03    75
# 0,01    74
# 0,13    74
# 0,25    74
# 0,19    73
# 0,22    71
# 0,17    70
# 0,1     70
# 0,29    70
# 0,16    67
# 0,24    66
# 0,12    66
# 0,02    64
# 0,14    64
# 0,11    63
# 0,04    62
# 0,07    62
# 0,2     62
# 0,23    62
# 0,05    58
# 0,09    58
# 0,26    58
# 0,28    55
# 0,15    54
# 0,06    53
# 0,18    53
# 0,0     29
# 0,3     26
# Name: count, dtype: int64
# -----------
# TOTAL VALUE
# Total Value
# 0,0       1753
# 871,24       1
# 109,22       1
# 66,67        1
# 69,26        1
#           ...
# 20,02        1
# 61,41        1
# 752,46       1
# 8,19         1
# 437,85       1
# Name: count, Length: 248, dtype: int64
# -----------
# PAYMENT METHOD
# Payment Method
# Bank Transfer       73
# Credit Card         67
# PayPal              57
# Cash on Delivery    50
# Name: count, dtype: int64
# -----------
# SHIPPING METHOD
# Shipping Method
# Express     90
# Same day    82
# Standard    75
# Name: count, dtype: int64
# -----------
# REGION
# Region
# South      435
# East       402
# Central    398
# North      396
# West       369
# Name: count, dtype: int64
# -----------
# CUSTOMER GENDER
# Customer Gender
# F        997
# M        915
# Other     88
# Name: count, dtype: int64
# -----------
# DEVICE
# Device
# TABLET     696
# Mobile     676
# Desktop    628
# Name: count, dtype: int64
# -----------
# COUPON USED
# Coupon Used
# No     132
# Yes    115
# Name: count, dtype: int64
# -----------
# BROWSER
# Browser
# Ottttther       443
# Eddddge         431
# Chrooome        411
# Firefoxxxxxx    365
# Safaaaaari      350
# Name: count, dtype: int64
# -----------
# REFERRAL SOURCE
# Referral Source
# Organic    551
# Social     493
# Email      482
# PAID       474
# Name: count, dtype: int64
# -----------

# %%
df.sample(5)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 645       646     B  2022-03-09           0             HOME      P1942
# 1667     1668     B  2022-03-25           0           BEAUTY      P1568
# 195       196     A  2022-02-19           0           SPORTS      P1042
# 273       274     B  2022-02-28           0           BEAUTY      P1025
# 780       781     B  2022-03-01           0             HOME      P1755
#
#        Product Name  Quantity   Price Discount Total Value Payment Method  \
# 645            Sofa         0  183,69     0,15         0,0            NaN
# 1667        Mascara         0   62,69     0,26         0,0            NaN
# 195   Tennis Racket         0  181,73     0,05         0,0            NaN
# 273        Lipstick         0   82,88     0,03         0,0            NaN
# 780            Lamp         0  180,63     0,03         0,0            NaN
#
#      Shipping Method   Region  Customer Age Customer Gender   Device  \
# 645              NaN    South          38.0               F   Mobile
# 1667             NaN  Central          63.0               F   Mobile
# 195              NaN     East          21.0               M  Desktop
# 273              NaN  Central          65.0               M   Mobile
# 780              NaN    South          42.0               F   TABLET
#
#       Session Duration Coupon Used    Browser Referral Source
# 645                 25         NaN  Ottttther            PAID
# 1667                 5         NaN   Chrooome         Organic
# 195                  7         NaN  Ottttther            PAID
# 273                 24         NaN  Ottttther          Social
# 780                  1         NaN   Chrooome          Social

# %%
print(f"Mi data frame tiene {df.shape[0]} filas y {df.shape[1]} columnas")
# Out:
# Mi data frame tiene 2000 filas y 21 columnas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User Id           2000 non-null   int64
#  1   Group             2000 non-null   object
#  2   Visit Date        2000 non-null   object
#  3   Conversion        2000 non-null   int64
#  4   Product Category  2000 non-null   object
#  5   Product Id        2000 non-null   object
#  6   Product Name      2000 non-null   object
#  7   Quantity          2000 non-null   int64
#  8   Price             1960 non-null   object
#  9   Discount          1960 non-null   object
#  10  Total Value       2000 non-null   object
#  11  Payment Method    247 non-null    object
#  12  Shipping Method   247 non-null    object
#  13  Region            2000 non-null   object
#  14  Customer Age      1960 non-null   float64
#  15  Customer Gender   2000 non-null   object
#  16  Device            2000 non-null   object
#  17  Session Duration  2000 non-null   int64
#  18  Coupon Used       247 non-null    object
#  19  Browser           2000 non-null   object
#  20  Referral Source   2000 non-null   object
# dtypes: float64(1), int64(4), object(16)
# memory usage: 328.3+ KB

# %%
df.isnull().sum()/ df.shape[0] * 100
# Out:
# User Id              0.00
# Group                0.00
# Visit Date           0.00
# Conversion           0.00
# Product Category     0.00
# Product Id           0.00
# Product Name         0.00
# Quantity             0.00
# Price                2.00
# Discount             2.00
# Total Value          0.00
# Payment Method      87.65
# Shipping Method     87.65
# Region               0.00
# Customer Age         2.00
# Customer Gender      0.00
# Device               0.00
# Session Duration     0.00
# Coupon Used         87.65
# Browser              0.00
# Referral Source      0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.select_dtypes(include="O").columns:
  print(col.upper())
  print(df[col].value_counts())
  print('-----------')
# Out:
# GROUP
# Group
# B    1013
# A     987
# Name: count, dtype: int64
# -----------
# VISIT DATE
# Visit Date
# 2022-01-28    35
# 2022-02-16    34
# 2022-02-28    32
# 2022-01-19    31
# 2022-01-21    31
#               ..
# 2022-01-18    15
# 2022-03-21    14
# 2022-03-30    14
# 2022-02-21    12
# 2022-01-31    10
# Name: count, Length: 90, dtype: int64
# -----------
# PRODUCT CATEGORY
# Product Category
# FASHHION       321
# BOOKS          291
# HOME           287
# SPORTS         282
# TOYS           276
# ELECTRONICS    275
# BEAUTY         268
# Name: count, dtype: int64
# -----------
# PRODUCT ID
# Product Id
# P1416    8
# P1782    8
# P1848    7
# P1605    7
# P1798    7
#         ..
# P1774    1
# P1096    1
# P1120    1
# P1196    1
# P1805    1
# Name: count, Length: 867, dtype: int64
# -----------
# PRODUCT NAME
# Product Name
# Science Fiction    85
# Smartphone         84
# Jeans              84
# Mystery            82
# Table              82
# Sofa               82
# Dress              81
# Sneakers           81
# Football           77
# Action Figure      75
# T-shirt            75
# Mascara            74
# Doll               73
# Headphones         72
# Lamp               72
# Running Shoes      72
# Tennis Racket      72
# Perfume            71
# Novel              69
# Lipstick           69
# Board Game         69
# Gym Bag            61
# Camera             60
# Puzzle             59
# Laptop             59
# Biography          55
# Lotion             54
# Chair              51
# Name: count, dtype: int64
# -----------
# PRICE
# Price
# 19,99     3
# 47,83     2
# 193,17    2
# 22,8      2
# 38,12     2
#          ..
# 198,08    1
# 14,01     1
# 498,58    1
# 102,32    1
# 7,8       1
# Name: count, Length: 1887, dtype: int64
# -----------
# DISCOUNT
# Discount
# 0,08    76
# 0,21    76
# 0,27    75
# 0,03    75
# 0,01    74
# 0,13    74
# 0,25    74
# 0,19    73
# 0,22    71
# 0,17    70
# 0,1     70
# 0,29    70
# 0,16    67
# 0,24    66
# 0,12    66
# 0,02    64
# 0,14    64
# 0,11    63
# 0,04    62
# 0,07    62
# 0,2     62
# 0,23    62
# 0,05    58
# 0,09    58
# 0,26    58
# 0,28    55
# 0,15    54
# 0,06    53
# 0,18    53
# 0,0     29
# 0,3     26
# Name: count, dtype: int64
# -----------
# TOTAL VALUE
# Total Value
# 0,0       1753
# 871,24       1
# 109,22       1
# 66,67        1
# 69,26        1
#           ...
# 20,02        1
# 61,41        1
# 752,46       1
# 8,19         1
# 437,85       1
# Name: count, Length: 248, dtype: int64
# -----------
# PAYMENT METHOD
# Payment Method
# Bank Transfer       73
# Credit Card         67
# PayPal              57
# Cash on Delivery    50
# Name: count, dtype: int64
# -----------
# SHIPPING METHOD
# Shipping Method
# Express     90
# Same day    82
# Standard    75
# Name: count, dtype: int64
# -----------
# REGION
# Region
# South      435
# East       402
# Central    398
# North      396
# West       369
# Name: count, dtype: int64
# -----------
# CUSTOMER GENDER
# Customer Gender
# F        997
# M        915
# Other     88
# Name: count, dtype: int64
# -----------
# DEVICE
# Device
# TABLET     696
# Mobile     676
# Desktop    628
# Name: count, dtype: int64
# -----------
# COUPON USED
# Coupon Used
# No     132
# Yes    115
# Name: count, dtype: int64
# -----------
# BROWSER
# Browser
# Ottttther       443
# Eddddge         431
# Chrooome        411
# Firefoxxxxxx    365
# Safaaaaari      350
# Name: count, dtype: int64
# -----------
# REFERRAL SOURCE
# Referral Source
# Organic    551
# Social     493
# Email      482
# PAID       474
# Name: count, dtype: int64
# -----------
